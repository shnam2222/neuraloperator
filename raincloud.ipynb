# %%
import numpy as np
import ptitprince as pt
from scipy import io
import matplotlib.pyplot as plt
import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items

# %%
# import matlab data in the form of pandas dataset

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_2500_epochs_100_0.mat')
Network = np.expand_dims(["FNO"]*2000,axis=-1)
FNO_data = np.concatenate((Network, 2500*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
FNO_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
FNO_df = pd.DataFrame(FNO_data, columns=['Network','Test Samples'])
FNO_df = pd.concat([FNO_df, FNO_RMSE], axis = 1)

# %%
dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_2500_epochs_100_0.mat')
Network = np.expand_dims(["UNet"]*2000,axis=-1)
UNet_data = np.concatenate((Network, 2500*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
UNet_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
UNet_df = pd.DataFrame(UNet_data, columns=['Network','Test Samples'])
UNet_df = pd.concat([UNet_df, UNet_RMSE], axis = 1)

# %%
total_df_2500 = pd.concat([FNO_df, UNet_df])
print(total_df_2500)
# Out:
#      Network Test Samples      RMSE
# 0        FNO       2500.0  0.037952
# 1        FNO       2500.0  0.050184
# 2        FNO       2500.0  0.034765
# 3        FNO       2500.0  0.060564
# 4        FNO       2500.0  0.058512
# ...      ...          ...       ...
# 1995    UNet       2500.0  0.123443
# 1996    UNet       2500.0  1.114539
# 1997    UNet       2500.0  0.087851
# 1998    UNet       2500.0  0.503792
# 1999    UNet       2500.0  0.215909
#
# [4000 rows x 3 columns]

# %%
# import matlab data in the form of pandas dataset

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_5000_epochs_100_0.mat')
label = np.expand_dims(["FNO"]*2000,axis=-1)
FNO_data = np.concatenate((label, 5000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
FNO_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
FNO_df = pd.DataFrame(FNO_data, columns=['Network','Test Samples'])
FNO_df = pd.concat([FNO_df, FNO_RMSE], axis = 1)

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_5000_epochs_100_0.mat')
label = np.expand_dims(["UNet"]*2000,axis=-1)
UNet_data = np.concatenate((label, 5000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
UNet_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
UNet_df = pd.DataFrame(UNet_data, columns=['Network','Test Samples'])
UNet_df = pd.concat([UNet_df, UNet_RMSE], axis = 1)

total_df_5000 = pd.concat([FNO_df, UNet_df])

# %%
# import matlab data in the form of pandas dataset

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_10000_epochs_100_0.mat')
label = np.expand_dims(["FNO"]*2000,axis=-1)
FNO_data = np.concatenate((label, 10000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
FNO_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
FNO_df = pd.DataFrame(FNO_data, columns=['Network','Test Samples'])
FNO_df = pd.concat([FNO_df, FNO_RMSE], axis = 1)

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_10000_epochs_100_0.mat')
label = np.expand_dims(["UNet"]*2000,axis=-1)
UNet_data = np.concatenate((label, 10000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
UNet_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
UNet_df = pd.DataFrame(UNet_data, columns=['Network','Test Samples'])
UNet_df = pd.concat([UNet_df, UNet_RMSE], axis = 1)

total_df_10000 = pd.concat([FNO_df, UNet_df])

# %%
# import matlab data in the form of pandas dataset

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_20000_epochs_100_0.mat')
label = np.expand_dims(["FNO"]*2000,axis=-1)
FNO_data = np.concatenate((label, 20000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
FNO_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
FNO_df = pd.DataFrame(FNO_data, columns=['Network','Test Samples'])
FNO_df = pd.concat([FNO_df, FNO_RMSE], axis = 1)

dataset =  io.loadmat('C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_20000_epochs_100_0.mat')
label = np.expand_dims(["UNet"]*2000,axis=-1)
UNet_data = np.concatenate((label, 20000*np.ones_like(np.transpose(dataset['Test_Results']))), axis = 1)
UNet_RMSE = pd.DataFrame(np.transpose(dataset['Test_Results']), columns=['RMSE'])
UNet_df = pd.DataFrame(UNet_data, columns=['Network','Test Samples'])
UNet_df = pd.concat([UNet_df, UNet_RMSE], axis = 1)

total_df_20000 = pd.concat([FNO_df, UNet_df])

# %%
total_df = pd.concat([total_df_2500, total_df_5000, total_df_10000, total_df_20000])

# %%
dx = 'Test Samples'; dy = 'RMSE'; ort = "h"; pal = "Set2"; sigma = .2 ; dhue = 'Network'
f, ax = plt.subplots(figsize=(12, 10))

ax=pt.RainCloud(x = dx, y = dy, hue = dhue, data = total_df, palette = pal, bw = sigma, width_viol = .7,
                ax = ax, orient = ort , alpha = .65, dodge = True, pointplot = True)
plt.xlim([0,0.3])
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\ptitprince\PtitPrince.py:1129: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0.0}` instead.
#
#   sns.pointplot(
# (0.0, 0.3)

# %%
train_time_FNO = []
train_time_UNet = []

# %%
filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_2500_epochs_100_'

FNO_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    FNO_time = np.append(FNO_time, float(time))

train_time_FNO = np.append(train_time_FNO, np.average(FNO_time))


filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_2500_epochs_100_'

UNet_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    UNet_time = np.append(UNet_time, float(time))

train_time_UNet = np.append(train_time_UNet, np.average(UNet_time))

filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_5000_epochs_100_'

FNO_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    FNO_time = np.append(FNO_time, float(time))

train_time_FNO = np.append(train_time_FNO, np.average(FNO_time))


filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_5000_epochs_100_'

UNet_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    UNet_time = np.append(UNet_time, float(time))

train_time_UNet = np.append(train_time_UNet, np.average(UNet_time))

filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_10000_epochs_100_'

FNO_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    FNO_time = np.append(FNO_time, float(time))

train_time_FNO = np.append(train_time_FNO, np.average(FNO_time))


filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_10000_epochs_100_'

UNet_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    UNet_time = np.append(UNet_time, float(time))

train_time_UNet = np.append(train_time_UNet, np.average(UNet_time))

filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\FNO_n_train_20000_epochs_100_'

FNO_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    FNO_time = np.append(FNO_time, float(time))

train_time_FNO = np.append(train_time_FNO, np.average(FNO_time))


filename = 'C:\\Users\\user\\archive\\neuraloperator\\Adjoint\\Benchmark\\UNet_n_train_20000_epochs_100_'

UNet_time = []
for i in range (1):
    dataset =  io.loadmat(filename+str(i)+'.mat')
    time = dataset["Training_Time"]
    UNet_time = np.append(UNet_time, float(time))

train_time_UNet = np.append(train_time_UNet, np.average(UNet_time))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_33580\3643913554.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   FNO_time = np.append(FNO_time, float(time))
# C:\Users\user\AppData\Local\Temp\ipykernel_33580\3643913554.py:18: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   UNet_time = np.append(UNet_time, float(time))
# C:\Users\user\AppData\Local\Temp\ipykernel_33580\3643913554.py:28: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...

# %%
print(train_time_FNO)
print(train_time_UNet)
# Out:
# [ 28.9017575  51.4050179  91.0439697 179.4700367]
# [ 58.6690807 107.4343446 190.4025932 392.6716743]

# %%
plt.figure()
plt.xlabel("Training Sets")
plt.ylabel("Training Time(s)")
x = [2500, 5000, 10000, 20000]
plt.plot(x, train_time_FNO, label = "FNO")
plt.plot(x, train_time_UNet, label = "UNet")
plt.xticks(x)
plt.legend()
plt.show()
